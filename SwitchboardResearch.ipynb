# %% [markdown]
# <a href="https://colab.research.google.com/github/ricrosales/CareerAdvice/blob/master/SwitchboardResearch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests

BASE = "http://54.191.187.100:8080/"

response = requests.get(BASE + "college?id=100654")
print(response.json())
print(response.status_code)
# Out:
# {'AWARD_LEVELS': 'Bachelor_s degreeMaster_s degreePost_master_s certificateDoctor_s degree _ research_scholarship', 'CALENDAR_SYSTEM': 'Semester', 'CAMPUS_SETTING': 'City: Midsize', 'CARNEGIE_CLASSIFICATION': 'Master_s Colleges & Universities: Larger Programs', 'CITY': 'Normal', 'CONTROL': 'Public', 'DISTANCE_LEARNING': 'Offers undergraduate courses and_or programs', 'INSTITUTION_CATEGORY': 'Degree_granting_ primarily baccalaureate or above', 'LEVEL': 'Four or more years', 'NAME': 'Alabama A & M University', 'OPEID': '00100200', 'RELIGIOUS_AFFILIATION': 'Not applicable', 'REPORTING_METHOD': 'Student charges for full academic year and fall GR_SFA_retention rate cohort', 'STATE': 'AL', 'TITLE_IV_INSTITUTION': 'Participates in Title IV federal financial aid programs', 'UNITID': '100654', 'WEB_ADDRESS': 'www.aamu.edu_', 'MEN_NUMBER_ADMITTED': 2828, 'MEN_NUMBER_APPLIED': 3160, 'MEN_NUMBER_ENROLLED_FULL_TIME': 650, 'MEN_NUMBER_ENROLLED_PART_TIME': 2, 'TOTAL_NUMBER_ADMITTED': 8789, 'TOTAL_N
# ...

# %%
"""
Note: Need to fix overwritting issue for SAT/ACT and Race quantites

Columns:
NAME
MEN_NUMBER_ADMITTED
MEN_NUMBER_APPLIED
MEN_NUMBER_ENROLLED_FULL_TIME
MEN_NUMBER_ENROLLED_PART_TIME
TOTAL_NUMBER_ADMITTED
TOTAL_NUMBER_APPLIED
TOTAL_NUMBER_ENROLLED_FULL_TIME
TOTAL_NUMBER_ENROLLED_PART_TIME
WOMEN_NUMBER_ADMITTED
WOMEN_NUMBER_APPLIED
WOMEN_NUMBER_ENROLLED_FULL_TIME
WOMEN_NUMBER_ENROLLED_PART_TIME
MATH_25TH_PERCENTILE
MATH_75TH_PERCENTILE
SAT_EVIDENCE_BASED_READING_AND_WRITING_25TH_PERCENTILE
SAT_EVIDENCE_BASED_READING_AND_WRITING_75TH_PERCENTILE
COMPOSITE_25TH_PERCENTILE
COMPOSITE_75TH_PERCENTILE
ENGLISH_25TH_PERCENTILE
ENGLISH_75TH_PERCENTILE
UG_ANY_GRANT_OR_SCHOLARSHIP_AID_AVERAGE_AMOUNT_OF_AID_RECEIVED
UG_ANY_GRANT_OR_SCHOLARSHIP_AID_PERCENT_RECEIVING_AID
UG_FEDERAL_STUDENT_LOANS_AVERAGE_AMOUNT_OF_AID_RECEIVED
UG_FEDERAL_STUDENT_LOANS_PERCENT_RECEIVING_AID
UG_PELL_GRANTS_AVERAGE_AMOUNT_OF_AID_RECEIVED
UG_PELL_GRANTS_PERCENT_RECEIVING_AID
FT_ANY_STUDENT_FINANCIAL_AID_AVERAGE_AMOUNT_OF_AID_RECEIVED
FT
RACE_ETHNICITY_UNKNOWN_DOCTOR_S_PROFESSIONAL_PRACTICE
RACE_ETHNICITY_UNKNOWN_DOCTOR_S_RESEARCH_SCHOLARSHIP
RACE_ETHNICITY_UNKNOWN_MASTER_S
TWO_OR_MORE_RACES_ASSOCIATE_S
TWO_OR_MORE_RACES_BACHELOR_S
TWO_OR_MORE_RACES_CERTIFICATES_ABOVE_BACHELOR_S
TWO_OR_MORE_RACES_CERTIFICATES_BELOW_BACHELOR_S
TWO_OR_MORE_RACES_DOCTOR_S_OTHER
TWO_OR_MORE_RACES_DOCTOR_S_PROFESSIONAL_PRACTICE
TWO_OR_MORE_RACES_DOCTOR_S_RESEARCH_SCHOLARSHIP
TWO_OR_MORE_RACES_MASTER_S
WHITE_ASSOCIATE_S
WHITE_BACHELOR_S
WHITE_CERTIFICATES_ABOVE_BACHELOR_S
WHITE_CERTIFICATES_BELOW_BACHELOR_S
WHITE_DOCTOR_S_OTHER
WHITE_DOCTOR_S_PROFESSIONAL_PRACTICE
WHITE_DOCTOR_S_RESEARCH_SCHOLARSHIP
WHITE_MASTER_S
"""

# %%
a = response.json()

# %%
a.keys()
# Out:
# dict_keys(['AWARD_LEVELS', 'CALENDAR_SYSTEM', 'CAMPUS_SETTING', 'CARNEGIE_CLASSIFICATION', 'CITY', 'CONTROL', 'DISTANCE_LEARNING', 'INSTITUTION_CATEGORY', 'LEVEL', 'NAME', 'OPEID', 'RELIGIOUS_AFFILIATION', 'REPORTING_METHOD', 'STATE', 'TITLE_IV_INSTITUTION', 'UNITID', 'WEB_ADDRESS', 'MEN_NUMBER_ADMITTED', 'MEN_NUMBER_APPLIED', 'MEN_NUMBER_ENROLLED_FULL_TIME', 'MEN_NUMBER_ENROLLED_PART_TIME', 'TOTAL_NUMBER_ADMITTED', 'TOTAL_NUMBER_APPLIED', 'TOTAL_NUMBER_ENROLLED_FULL_TIME', 'TOTAL_NUMBER_ENROLLED_PART_TIME', 'WOMEN_NUMBER_ADMITTED', 'WOMEN_NUMBER_APPLIED', 'WOMEN_NUMBER_ENROLLED_FULL_TIME', 'WOMEN_NUMBER_ENROLLED_PART_TIME', 'MATH_25TH_PERCENTILE', 'MATH_75TH_PERCENTILE', 'SAT_EVIDENCE_BASED_READING_AND_WRITING_25TH_PERCENTILE', 'SAT_EVIDENCE_BASED_READING_AND_WRITING_75TH_PERCENTILE', 'COMPOSITE_25TH_PERCENTILE', 'COMPOSITE_75TH_PERCENTILE', 'ENGLISH_25TH_PERCENTILE', 'ENGLISH_75TH_PERCENTILE', 'BOOKS_AND_SUPPLIES', 'IN_STATE', 'OFF_CAMPUS_NOT_WITH_FAMILY_', 'OFF_CAMPUS_NOT_WITH_FAM
# ...
